# %%
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.decomposition import PCA
import pandas as pd
# import tensorflow as tf
# import keras
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import numpy as np

# %%
file_1 = "Wine_Data/winequality-red (1).csv"
file_2 = "Wine_Data/winequality-white.csv"

# %%
df_1 = pd.read_csv(file_1, sep='\;')
# Out:
# /var/folders/fx/8tn4frpd2fb4cg3mdhxpk_3w0000gn/T/ipykernel_14613/2508800702.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df_1 = pd.read_csv(file_1, sep='\;')

# %%
# red = 1 white = 0

# %%
# df_1['color']='1'

# %%
df_1
# Out:
#       "fixed acidity  ""volatile acidity""  ""citric acid""  \
# 0                7.4                 0.700             0.00
# 1                7.8                 0.880             0.00
# 2                7.8                 0.760             0.04
# 3               11.2                 0.280             0.56
# 4                7.4                 0.700             0.00
# ...              ...                   ...              ...
# 1594             6.2                 0.600             0.08
# 1595             5.9                 0.550             0.10
# 1596             6.3                 0.510             0.13
# 1597             5.9                 0.645             0.12
# 1598             6.0                 0.310             0.47
#
#       ""residual sugar""  ""chlorides""  ""free sulfur dioxide""  \
# 0                    1.9          0.076                     11.0
# 1                    2.6          0.098                     25.0
# 2                    2.3          0.092                     15.0
# 3                    1.9          0.075                     17.0
# 4                    1.9          0.076                     11.0
# ...                  ...            ...                      ...
# 1594                 2.0          0.090                     32.0
# 1595                 2.2          0.062                     39.0
# 1596                 2.3          0.076                     29.0
# 1597                 2.0          0.075                     32.0
# 1598                 3.6          0.067                     18.0
#
#       ""total sulfur dioxide""  ""density""  ""pH""  ""sulphates""  \
# 0                         34.0      0.99780    3.51           0.56
# 1                         67.0      0.99680    3.20           0.68
# 2                         54.0      0.99700    3.26           0.65
# 3                         60.0      0.99800    3.16           0.58
# 4                         34.0      0.99780    3.51           0.56
# ...                        ...          ...     ...            ...
# 1594                      44.0      0.99490    3.45           0.58
# 1595                      51.0      0.99512    3.52           0.76
# 1596                      40.0      0.99574    3.42           0.75
# 1597                      44.0      0.99547    3.57           0.71
# 1598                      42.0      0.99549    3.39           0.66
#
#       ""alcohol""  ""quality"""
# 0             9.4             5
# 1             9.8             5
# 2             9.8             5
# 3             9.8             6
# 4             9.4             5
# ...           ...           ...
# 1594         10.5             5
# 1595         11.2             6
# 1596         11.0             6
# 1597         10.2             5
# 1598         11.0             6
#
# [1599 rows x 12 columns]

# %%
df_2 = pd.read_csv(file_2, sep='\;')
# Out:
# /var/folders/fx/8tn4frpd2fb4cg3mdhxpk_3w0000gn/T/ipykernel_14613/435387210.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df_2 = pd.read_csv(file_2, sep='\;')

# %%
# df_2['color']= '0'

# %%
df_2
# Out:
#       "fixed acidity  ""volatile acidity""  ""citric acid""  \
# 0                7.0                  0.27             0.36
# 1                6.3                  0.30             0.34
# 2                8.1                  0.28             0.40
# 3                7.2                  0.23             0.32
# 4                7.2                  0.23             0.32
# ...              ...                   ...              ...
# 4893             6.2                  0.21             0.29
# 4894             6.6                  0.32             0.36
# 4895             6.5                  0.24             0.19
# 4896             5.5                  0.29             0.30
# 4897             6.0                  0.21             0.38
#
#       ""residual sugar""  ""chlorides""  ""free sulfur dioxide""  \
# 0                   20.7          0.045                     45.0
# 1                    1.6          0.049                     14.0
# 2                    6.9          0.050                     30.0
# 3                    8.5          0.058                     47.0
# 4                    8.5          0.058                     47.0
# ...                  ...            ...                      ...
# 4893                 1.6          0.039                     24.0
# 4894                 8.0          0.047                     57.0
# 4895                 1.2          0.041                     30.0
# 4896                 1.1          0.022                     20.0
# 4897                 0.8          0.020                     22.0
#
#       ""total sulfur dioxide""  ""density""  ""pH""  ""sulphates""  \
# 0                        170.0      1.00100    3.00           0.45
# 1                        132.0      0.99400    3.30           0.49
# 2                         97.0      0.99510    3.26           0.44
# 3                        186.0      0.99560    3.19           0.40
# 4                        186.0      0.99560    3.19           0.40
# ...                        ...          ...     ...            ...
# 4893                      92.0      0.99114    3.27           0.50
# 4894                     168.0      0.99490    3.15           0.46
# 4895                     111.0      0.99254    2.99           0.46
# 4896                     110.0      0.98869    3.34           0.38
# 4897                      98.0      0.98941    3.26           0.32
#
#       ""alcohol""  ""quality"""
# 0             8.8             6
# 1             9.5             6
# 2            10.1             6
# 3             9.9             6
# 4             9.9             6
# ...           ...           ...
# 4893         11.2             6
# 4894          9.6             5
# 4895          9.4             6
# 4896         12.8             7
# 4897         11.8             6
#
# [4898 rows x 12 columns]

# %%
# dataframes = [df_1, df_2]
# result_df = pd.concat(dataframes)

# %%
# result_df

# %%
from sklearn.preprocessing import QuantileTransformer

# %%
# color_dummy = pd.get_dummies(result_df['color'])
# color_dummy

# %%
df_1
# Out:
#       "fixed acidity  ""volatile acidity""  ""citric acid""  \
# 0                7.4                 0.700             0.00
# 1                7.8                 0.880             0.00
# 2                7.8                 0.760             0.04
# 3               11.2                 0.280             0.56
# 4                7.4                 0.700             0.00
# ...              ...                   ...              ...
# 1594             6.2                 0.600             0.08
# 1595             5.9                 0.550             0.10
# 1596             6.3                 0.510             0.13
# 1597             5.9                 0.645             0.12
# 1598             6.0                 0.310             0.47
#
#       ""residual sugar""  ""chlorides""  ""free sulfur dioxide""  \
# 0                    1.9          0.076                     11.0
# 1                    2.6          0.098                     25.0
# 2                    2.3          0.092                     15.0
# 3                    1.9          0.075                     17.0
# 4                    1.9          0.076                     11.0
# ...                  ...            ...                      ...
# 1594                 2.0          0.090                     32.0
# 1595                 2.2          0.062                     39.0
# 1596                 2.3          0.076                     29.0
# 1597                 2.0          0.075                     32.0
# 1598                 3.6          0.067                     18.0
#
#       ""total sulfur dioxide""  ""density""  ""pH""  ""sulphates""  \
# 0                         34.0      0.99780    3.51           0.56
# 1                         67.0      0.99680    3.20           0.68
# 2                         54.0      0.99700    3.26           0.65
# 3                         60.0      0.99800    3.16           0.58
# 4                         34.0      0.99780    3.51           0.56
# ...                        ...          ...     ...            ...
# 1594                      44.0      0.99490    3.45           0.58
# 1595                      51.0      0.99512    3.52           0.76
# 1596                      40.0      0.99574    3.42           0.75
# 1597                      44.0      0.99547    3.57           0.71
# 1598                      42.0      0.99549    3.39           0.66
#
#       ""alcohol""  ""quality"""
# 0             9.4             5
# 1             9.8             5
# 2             9.8             5
# 3             9.8             6
# 4             9.4             5
# ...           ...           ...
# 1594         10.5             5
# 1595         11.2             6
# 1596         11.0             6
# 1597         10.2             5
# 1598         11.0             6
#
# [1599 rows x 12 columns]

# %%
clean_df_r= df_1.rename(columns={'"fixed acidity':'fixed acidity',
           '""volatile acidity""':'volatile acidity',
                    '""citric acid""':'citric acid',
                    '""residual sugar""':'residual sugar',
                    '""chlorides""':'chlorides',
                    '""free sulfur dioxide""':'free sulfure dioxide',
                    '""total sulfur dioxide""':'total sulfur dioxide',
                    '""density""':'density',
                    '""pH""':'pH',
                    '""sulphates""':'sulphates',
                    '""alcohol""':'alcohol',
                    '""quality"""':'quality'})

# %%
clean_df_w= df_2.rename(columns={'"fixed acidity':'fixed acidity',
           '""volatile acidity""':'volatile acidity',
                    '""citric acid""':'citric acid',
                    '""residual sugar""':'residual sugar',
                    '""chlorides""':'chlorides',
                    '""free sulfur dioxide""':'free sulfure dioxide',
                    '""total sulfur dioxide""':'total sulfur dioxide',
                    '""density""':'density',
                    '""pH""':'pH',
                    '""sulphates""':'sulphates',
                    '""alcohol""':'alcohol',
                    '""quality"""':'quality'})

# %%
clean_df_w
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfure dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                     45.0                 170.0  1.00100  3.00       0.45
# 1                     14.0                 132.0  0.99400  3.30       0.49
# 2                     30.0                  97.0  0.99510  3.26       0.44
# 3                     47.0                 186.0  0.99560  3.19       0.40
# 4                     47.0                 186.0  0.99560  3.19       0.40
# ...                    ...                   ...      ...   ...        ...
# 4893                  24.0                  92.0  0.99114  3.27       0.50
# 4894                  57.0                 168.0  0.99490  3.15       0.46
# 4895                  30.0                 111.0  0.99254  2.99       0.46
# 4896                  20.0                 110.0  0.98869  3.34       0.38
# 4897                  22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
clean_df_w['best quality']=[1 if x>6 else 0 for x in clean_df_w.quality]
clean_df_w.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfure dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  45.0                 170.0   1.0010  3.00       0.45
# 1                  14.0                 132.0   0.9940  3.30       0.49
# 2                  30.0                  97.0   0.9951  3.26       0.44
# 3                  47.0                 186.0   0.9956  3.19       0.40
# 4                  47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  best quality
# 0      8.8        6             0
# 1      9.5        6             0
# 2     10.1        6             0
# 3      9.9        6             0
# 4      9.9        6             0

# %%
clean_df_w['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9])

# %%
clean_df_w['best quality'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
X = clean_df_w.drop(columns ={'quality', 'best quality'}, axis = 1)
y = clean_df_w['best quality']

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfure dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                     45.0                 170.0  1.00100  3.00       0.45
# 1                     14.0                 132.0  0.99400  3.30       0.49
# 2                     30.0                  97.0  0.99510  3.26       0.44
# 3                     47.0                 186.0  0.99560  3.19       0.40
# 4                     47.0                 186.0  0.99560  3.19       0.40
# ...                    ...                   ...      ...   ...        ...
# 4893                  24.0                  92.0  0.99114  3.27       0.50
# 4894                  57.0                 168.0  0.99490  3.15       0.46
# 4895                  30.0                 111.0  0.99254  2.99       0.46
# 4896                  20.0                 110.0  0.98869  3.34       0.38
# 4897                  22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol
# 0         8.8
# 1         9.5
# 2        10.1
# 3         9.9
# 4         9.9
# ...       ...
# 4893     11.2
# 4894      9.6
# 4895      9.4
# 4896     12.8
# 4897     11.8
#
# [4898 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split

### BEGIN SOLUTION

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_train_scaled
# Out:
# array([[-0.66770463, -0.28734949, -0.94253451, ..., -0.19632566,
#          0.09208801, -0.00834466],
#        [ 1.10380585,  0.20506195, -0.35973215, ..., -0.19632566,
#         -0.9646345 , -1.22762224],
#        [ 0.63140305,  0.99292025, -0.52624711, ..., -0.12946389,
#         -0.52433346, -0.41477052],
#        ...,
#        [ 0.86760445, -0.09038491,  1.55518988, ..., -1.13239039,
#          0.35626864,  0.72322189],
#        [-0.66770463, -0.38583178, -0.35973215, ..., -0.12946389,
#         -0.9646345 ,  0.07294051],
#        [ 1.45810795, -0.09038491,  0.13981272, ...,  0.20484494,
#          1.23687074, -0.08962983]])

# %%
X_test_scaled = scaler.transform(X_test)
X_test_scaled
# Out:
# array([[-1.02200673,  0.10657966,  0.6393576 , ..., -0.66435803,
#          0.8846299 ,  0.37098615],
#        [-1.73061092,  2.47015456, -1.44207939, ...,  0.07112141,
#          0.35626864,  2.186355  ],
#        [ 0.27710096, -0.28734949,  0.47284264, ...,  0.60601554,
#         -0.52433346,  1.37350327],
#        ...,
#        [-1.14010743, -1.46913694, -0.44298963, ...,  1.60894203,
#          1.32493095,  0.23551086],
#        [-0.07720114,  0.20506195, -0.35973215, ..., -1.06552862,
#         -1.49299576,  1.94249948],
#        [ 0.63140305, -0.28734949,  0.2230702 , ...,  0.00425964,
#         -0.43627325,  0.23551086]])

# %%
# Loop through different k values to find which has the highest accuracy.
# Note: We use only odd numbers because we don't want any ties.
train_scores = []
test_scores = []
for k in range(1, 50, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    train_score = knn.score(X_train, y_train)
    test_score = knn.score(X_test, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    
    
plt.plot(range(1, 50, 2), train_scores, marker='o')
plt.plot(range(1, 50, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy Score")
plt.show()
# Out:
# k: 1, Train/Test Score: 1.000/0.813
# k: 3, Train/Test Score: 0.885/0.787
# k: 5, Train/Test Score: 0.849/0.777
# k: 7, Train/Test Score: 0.832/0.771
# k: 9, Train/Test Score: 0.819/0.772
# k: 11, Train/Test Score: 0.813/0.767
# k: 13, Train/Test Score: 0.809/0.775
# k: 15, Train/Test Score: 0.802/0.773
# k: 17, Train/Test Score: 0.804/0.776
# k: 19, Train/Test Score: 0.802/0.771
# k: 21, Train/Test Score: 0.798/0.770
# k: 23, Train/Test Score: 0.799/0.767
# k: 25, Train/Test Score: 0.798/0.763
# k: 27, Train/Test Score: 0.796/0.771
# k: 29, Train/Test Score: 0.794/0.771
# k: 31, Train/Test Score: 0.793/0.771
# k: 33, Train/Test Score: 0.795/0.770
# k: 35, Train/Test Score: 0.793/0.767
# k: 37, Train/Test Score: 0.794/0.762
# k: 39, Train/Test Score: 0.793/0.765
# k: 41, Train/Test Score: 0.792/0.765
# k: 43, Train/Test Score: 0.793/0.768
# k: 45, Train/Test Score: 0.794/0.770
# k: 47, Train/Test Score: 0.794/0.766
# k: 49, Train/Test Score: 0.796/0.770

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
#number_input_features = 1199
hidden_nodes_layer1 =  6
hidden_nodes_layer2 = 2
#hidden_nodes_layer3 = 10
#hidden_nodes_layer4 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="sigmoid"))

# Third hidden layer
#nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="sigmoid"))

# Fourth hidden layer
#nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="sigmoid"))

# Output layer 

nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 72
#
#  dense_1 (Dense)             (None, 2)                 14
#
#  dense_2 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 89
# Trainable params: 89
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train_scaled.shape
# Out:
# (3673, 11)

# %%
y_train.shape
# Out:
# (3673,)

# %%
# Define the checkpoint path and filenames
#os.makedirs("checkpoints_optimized_1/",exist_ok=True)
#checkpoint_dir_1 = "checkpoints_optimized_1/weights.{epoch:02d}.hdf5"

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 115/115 [==============================] - 0s 848us/step - loss: 0.5610 - accuracy: 0.7885
# Epoch 2/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.5211 - accuracy: 0.7887
# Epoch 3/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4956 - accuracy: 0.7887
# Epoch 4/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4782 - accuracy: 0.7887
# Epoch 5/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4655 - accuracy: 0.7887
# Epoch 6/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4560 - accuracy: 0.7887
# Epoch 7/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4486 - accuracy: 0.7887
# Epoch 8/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4424 - accuracy: 0.7887
# Epoch 9/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4374 - accuracy: 0.7887
# Epoch 10/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4334 - accuracy: 0.7887
# Epoch 11/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4299 - accuracy: 0.7887
# Epoch 12/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4270 - accuracy: 0.7887
# Epoch 13/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4246 - accuracy: 0.7887
# Epoch 14/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4224 - accuracy: 0.7887
# Epoch 15/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4206 - accuracy: 0.7887
# Epoch 16/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4188 - accuracy: 0.7887
# Epoch 17/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4175 - accuracy: 0.7887
# Epoch 18/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4162 - accuracy: 0.7887
# Epoch 19/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4151 - accuracy: 0.7887
# Epoch 20/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4141 - accuracy: 0.7887
# Epoch 21/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4131 - accuracy: 0.7887
# Epoch 22/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4123 - accuracy: 0.7887
# Epoch 23/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4114 - accuracy: 0.7887
# Epoch 24/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4106 - accuracy: 0.7923
# Epoch 25/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4098 - accuracy: 0.7999
# Epoch 26/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4091 - accuracy: 0.8083
# Epoch 27/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4085 - accuracy: 0.8116
# Epoch 28/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4081 - accuracy: 0.8130
# Epoch 29/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4073 - accuracy: 0.8140
# Epoch 30/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4068 - accuracy: 0.8127
# Epoch 31/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4064 - accuracy: 0.8130
# Epoch 32/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4059 - accuracy: 0.8138
# Epoch 33/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4054 - accuracy: 0.8149
# Epoch 34/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4051 - accuracy: 0.8157
# Epoch 35/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4048 - accuracy: 0.8151
# Epoch 36/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4044 - accuracy: 0.8160
# Epoch 37/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4038 - accuracy: 0.8179
# Epoch 38/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4035 - accuracy: 0.8173
# Epoch 39/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4032 - accuracy: 0.8154
# Epoch 40/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4028 - accuracy: 0.8176
# Epoch 41/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4027 - accuracy: 0.8173
# Epoch 42/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4022 - accuracy: 0.8173
# Epoch 43/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4020 - accuracy: 0.8176
# Epoch 44/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4017 - accuracy: 0.8173
# Epoch 45/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4013 - accuracy: 0.8181
# Epoch 46/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4010 - accuracy: 0.8187
# Epoch 47/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4007 - accuracy: 0.8189
# Epoch 48/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4002 - accuracy: 0.8184
# Epoch 49/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4001 - accuracy: 0.8165
# Epoch 50/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3997 - accuracy: 0.8179
# Epoch 51/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3992 - accuracy: 0.8173
# Epoch 52/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3990 - accuracy: 0.8165
# Epoch 53/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3986 - accuracy: 0.8170
# Epoch 54/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3983 - accuracy: 0.8181
# Epoch 55/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3980 - accuracy: 0.8179
# Epoch 56/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3973 - accuracy: 0.8173
# Epoch 57/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3969 - accuracy: 0.8195
# Epoch 58/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3962 - accuracy: 0.8189
# Epoch 59/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3956 - accuracy: 0.8189
# Epoch 60/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3950 - accuracy: 0.8170
# Epoch 61/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3942 - accuracy: 0.8184
# Epoch 62/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3934 - accuracy: 0.8176
# Epoch 63/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3924 - accuracy: 0.8162
# Epoch 64/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3917 - accuracy: 0.8192
# Epoch 65/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3902 - accuracy: 0.8176
# Epoch 66/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3893 - accuracy: 0.8179
# Epoch 67/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3882 - accuracy: 0.8179
# Epoch 68/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3874 - accuracy: 0.8181
# Epoch 69/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3868 - accuracy: 0.8195
# Epoch 70/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3861 - accuracy: 0.8209
# Epoch 71/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3855 - accuracy: 0.8184
# Epoch 72/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3851 - accuracy: 0.8206
# Epoch 73/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3845 - accuracy: 0.8206
# Epoch 74/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3841 - accuracy: 0.8206
# Epoch 75/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3836 - accuracy: 0.8176
# Epoch 76/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3832 - accuracy: 0.8214
# Epoch 77/100
# 115/115 [==============================] - 0s 987us/step - loss: 0.3826 - accuracy: 0.8203
# Epoch 78/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3820 - accuracy: 0.8200
# Epoch 79/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3817 - accuracy: 0.8209
# Epoch 80/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3813 - accuracy: 0.8217
# Epoch 81/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3810 - accuracy: 0.8219
# Epoch 82/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3805 - accuracy: 0.8214
# Epoch 83/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3803 - accuracy: 0.8209
# Epoch 84/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8187
# Epoch 85/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3799 - accuracy: 0.8217
# Epoch 86/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3795 - accuracy: 0.8214
# Epoch 87/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3793 - accuracy: 0.8209
# Epoch 88/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3791 - accuracy: 0.8195
# Epoch 89/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3788 - accuracy: 0.8189
# Epoch 90/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3786 - accuracy: 0.8211
# Epoch 91/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3784 - accuracy: 0.8176
# Epoch 92/100
# 115/115 [==============================] - 0s 917us/step - loss: 0.3782 - accuracy: 0.8198
# Epoch 93/100
# 115/115 [==============================] - 0s 836us/step - loss: 0.3779 - accuracy: 0.8206
# Epoch 94/100
# 115/115 [==============================] - 0s 971us/step - loss: 0.3777 - accuracy: 0.8192
# Epoch 95/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3773 - accuracy: 0.8176
# Epoch 96/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3773 - accuracy: 0.8189
# Epoch 97/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3771 - accuracy: 0.8187
# Epoch 98/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3769 - accuracy: 0.8181
# Epoch 99/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3768 - accuracy: 0.8187
# Epoch 100/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3765 - accuracy: 0.8162

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f'Loss: {model_loss}, Accuracy: {model_accuracy}')
# Out:
# 39/39 - 0s - loss: 0.4225 - accuracy: 0.7951 - 158ms/epoch - 4ms/step
# Loss: 0.42247799038887024, Accuracy: 0.795102059841156

# %%
# Export our model to HDF5 file
nn.save("Wine_Enthusiast_Optimization_w.h5")

# %%
number_input_features = len(X_train_scaled[0])
#number_input_features = 1199
hidden_nodes_layer1 =  12
hidden_nodes_layer2 = 6
hidden_nodes_layer3 = 4
#hidden_nodes_layer4 = 5

nn_1 = tf.keras.models.Sequential()

# First hidden layer
nn_1.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn_1.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="sigmoid"))

# Third hidden layer
nn_1.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="sigmoid"))

# Fourth hidden layer
#nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="sigmoid"))

# Output layer 

nn_1.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 12)                144
#
#  dense_4 (Dense)             (None, 6)                 78
#
#  dense_5 (Dense)             (None, 4)                 28
#
#  dense_6 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn_1.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn_1.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 115/115 [==============================] - 0s 824us/step - loss: 0.5701 - accuracy: 0.7887
# Epoch 2/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.5079 - accuracy: 0.7887
# Epoch 3/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4845 - accuracy: 0.7887
# Epoch 4/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4663 - accuracy: 0.7887
# Epoch 5/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4519 - accuracy: 0.7887
# Epoch 6/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4407 - accuracy: 0.7887
# Epoch 7/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4318 - accuracy: 0.7887
# Epoch 8/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4250 - accuracy: 0.7887
# Epoch 9/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4201 - accuracy: 0.7887
# Epoch 10/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4152 - accuracy: 0.7942
# Epoch 11/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4110 - accuracy: 0.8116
# Epoch 12/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4067 - accuracy: 0.8143
# Epoch 13/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4026 - accuracy: 0.8154
# Epoch 14/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3991 - accuracy: 0.8154
# Epoch 15/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3953 - accuracy: 0.8157
# Epoch 16/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3933 - accuracy: 0.8140
# Epoch 17/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3906 - accuracy: 0.8143
# Epoch 18/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3884 - accuracy: 0.8140
# Epoch 19/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3863 - accuracy: 0.8146
# Epoch 20/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3852 - accuracy: 0.8170
# Epoch 21/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3833 - accuracy: 0.8135
# Epoch 22/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3829 - accuracy: 0.8135
# Epoch 23/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3808 - accuracy: 0.8146
# Epoch 24/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3799 - accuracy: 0.8151
# Epoch 25/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3788 - accuracy: 0.8154
# Epoch 26/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3776 - accuracy: 0.8181
# Epoch 27/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3768 - accuracy: 0.8187
# Epoch 28/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3761 - accuracy: 0.8184
# Epoch 29/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3754 - accuracy: 0.8187
# Epoch 30/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3743 - accuracy: 0.8179
# Epoch 31/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3737 - accuracy: 0.8187
# Epoch 32/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3729 - accuracy: 0.8184
# Epoch 33/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3722 - accuracy: 0.8181
# Epoch 34/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3715 - accuracy: 0.8214
# Epoch 35/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3711 - accuracy: 0.8198
# Epoch 36/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3701 - accuracy: 0.8200
# Epoch 37/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3697 - accuracy: 0.8209
# Epoch 38/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3693 - accuracy: 0.8203
# Epoch 39/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3686 - accuracy: 0.8206
# Epoch 40/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3679 - accuracy: 0.8214
# Epoch 41/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3672 - accuracy: 0.8203
# Epoch 42/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3669 - accuracy: 0.8198
# Epoch 43/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3661 - accuracy: 0.8225
# Epoch 44/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3657 - accuracy: 0.8211
# Epoch 45/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3652 - accuracy: 0.8206
# Epoch 46/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3642 - accuracy: 0.8219
# Epoch 47/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3635 - accuracy: 0.8195
# Epoch 48/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3632 - accuracy: 0.8217
# Epoch 49/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3628 - accuracy: 0.8195
# Epoch 50/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3618 - accuracy: 0.8209
# Epoch 51/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3615 - accuracy: 0.8203
# Epoch 52/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3612 - accuracy: 0.8189
# Epoch 53/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3604 - accuracy: 0.8203
# Epoch 54/100
# 115/115 [==============================] - 0s 902us/step - loss: 0.3600 - accuracy: 0.8203
# Epoch 55/100
# 115/115 [==============================] - 0s 945us/step - loss: 0.3597 - accuracy: 0.8195
# Epoch 56/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3585 - accuracy: 0.8206
# Epoch 57/100
# 115/115 [==============================] - 0s 880us/step - loss: 0.3588 - accuracy: 0.8219
# Epoch 58/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3581 - accuracy: 0.8228
# Epoch 59/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3574 - accuracy: 0.8244
# Epoch 60/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3569 - accuracy: 0.8252
# Epoch 61/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3570 - accuracy: 0.8247
# Epoch 62/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3563 - accuracy: 0.8274
# Epoch 63/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3554 - accuracy: 0.8260
# Epoch 64/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3553 - accuracy: 0.8268
# Epoch 65/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3548 - accuracy: 0.8263
# Epoch 66/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3541 - accuracy: 0.8258
# Epoch 67/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3541 - accuracy: 0.8260
# Epoch 68/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3538 - accuracy: 0.8263
# Epoch 69/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3530 - accuracy: 0.8255
# Epoch 70/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3530 - accuracy: 0.8274
# Epoch 71/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3524 - accuracy: 0.8279
# Epoch 72/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3521 - accuracy: 0.8247
# Epoch 73/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3513 - accuracy: 0.8271
# Epoch 74/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3512 - accuracy: 0.8279
# Epoch 75/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3505 - accuracy: 0.8241
# Epoch 76/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3504 - accuracy: 0.8266
# Epoch 77/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3497 - accuracy: 0.8247
# Epoch 78/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3495 - accuracy: 0.8285
# Epoch 79/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3495 - accuracy: 0.8271
# Epoch 80/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3489 - accuracy: 0.8258
# Epoch 81/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3486 - accuracy: 0.8279
# Epoch 82/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3480 - accuracy: 0.8279
# Epoch 83/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3484 - accuracy: 0.8274
# Epoch 84/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3478 - accuracy: 0.8277
# Epoch 85/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3468 - accuracy: 0.8277
# Epoch 86/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3468 - accuracy: 0.8293
# Epoch 87/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3464 - accuracy: 0.8271
# Epoch 88/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3461 - accuracy: 0.8277
# Epoch 89/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3455 - accuracy: 0.8293
# Epoch 90/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3451 - accuracy: 0.8279
# Epoch 91/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3450 - accuracy: 0.8274
# Epoch 92/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3447 - accuracy: 0.8296
# Epoch 93/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3442 - accuracy: 0.8285
# Epoch 94/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3442 - accuracy: 0.8277
# Epoch 95/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3442 - accuracy: 0.8307
# Epoch 96/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3437 - accuracy: 0.8271
# Epoch 97/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3434 - accuracy: 0.8277
# Epoch 98/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3431 - accuracy: 0.8288
# Epoch 99/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3425 - accuracy: 0.8301
# Epoch 100/100
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3424 - accuracy: 0.8301

# %%
model_loss, model_accuracy = nn_1.evaluate(X_test_scaled,y_test,verbose=2)
print(f'Loss: {model_loss}, Accuracy: {model_accuracy}')
# Out:
# 39/39 - 0s - loss: 0.4016 - accuracy: 0.8024 - 129ms/epoch - 3ms/step
# Loss: 0.40164920687675476, Accuracy: 0.8024489879608154

# %%
# Export our model to HDF5 file
nn_1.save("Wine_Enthusiast_Optimization_w_2.h5")

# %%
from sklearn.ensemble import RandomForestClassifier
#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)
#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train_scaled,y_train)
y_pred=clf.predict(X_test_scaled)

# %%
clf.score(X_test_scaled,y_test)
# Out:
# 0.8840816326530613

# %%
scaler.transform([clean_df_w.iloc[3,0:11].to_list()])
# Out:
# /Users/alexanderlorin/opt/anaconda3/envs/mlp/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ 0.39520166, -0.48431406, -0.10995972,  0.40124231,  0.5857816 ,
#          0.7029592 ,  1.13504717,  0.50697803,  0.00425964, -0.78851408,
#         -0.49605569]])

# %%
clf.predict(scaler.transform([clean_df_w.iloc[3,0:11].to_list()]))
# Out:
# /Users/alexanderlorin/opt/anaconda3/envs/mlp/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([0])

# %%
from joblib import dump, load

# %%
dump(clf, 'Wine_Enthusiast_RF_w.joblib')
# Out:
# ['Wine_Enthusiast_RF_w.joblib']

# %%
dump(scaler, 'scaler_RF_w.joblib')
# Out:
# ['scaler_RF_w.joblib']

# %%
clf = load('Wine_Enthusiast_RF_w.joblib')

# %%
df_2.plot()
# Out:
# <AxesSubplot:>
